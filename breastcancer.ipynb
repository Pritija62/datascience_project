# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(df.shape)
# Out:
# (569, 33)

# %%
df.drop(columns=["id"], inplace=True, errors="ignore")
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
print(df.isnull().sum())
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# ...

# %%
df.drop(columns=["Unnamed: 32"], inplace=True,errors="ignore")
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
print(df["diagnosis"].unique())
# Out:
# ['M' 'B']

# %%
df["diagnosis"] = df["diagnosis"].str.strip()

# %%
print(df["diagnosis"].unique())
# Out:
# ['M' 'B']

# %%
df["diagnosis"] = df["diagnosis"].map({"M": 1, "B": 0})

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.1 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 2.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 2.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.1 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.1 MB 2.2 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.2 MB/s eta 0:00:02
# ...

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Countplot
plt.figure(figsize=(6,4))
sns.countplot(x="diagnosis", data=df)
plt.xticks([0,1], ['Benign', 'Malignant'])
plt.title("Distribution of Diagnosis")
plt.show()

# %%
summary = pd.DataFrame({
    'Count': df['diagnosis'].value_counts(),
    'Percentage': df['diagnosis'].value_counts(normalize=True) * 100
})
summary.index = ['Benign', 'Malignant'] 
print(summary)
# Out:
#            Count  Percentage
# Benign       357   62.741652
# Malignant    212   37.258348

# %% [markdown]
# #### Findings
# Countplot of diagnosis showing distribution of benign vs malignant tumors.
#
# Out of 569 samples, 357 are benign (63%) and 212 are malignant (37%).
#
# The dataset is slightly imbalanced towards benign tumors.

# %%
# pie chart 
df['diagnosis'].value_counts().plot.pie(autopct='%1.1f%%', labels=['Benign','Malignant'], colors=['red','green'])
plt.title("Diagnosis Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# #### Findings
#  Pie chart showing the proportion of benign vs malignant tumors.
#
#  63% of tumors are benign, 37% are malignant.
#
#  Confirms the dataset imbalance visually

# %%
# Histogram of a Feature (radius_mean)
plt.figure(figsize=(8,4))
sns.histplot(df['radius_mean'], bins=30, kde=True)
plt.title("Distribution of Radius Mean")
plt.show()

# %% [markdown]
# #### Findings
# Histogram showing the distribution of radius_mean across all samples.
#
#  Most tumors have radius_mean between 12 and 18, with malignant tumors tending toward higher values.
#
#  radius_mean may be a good predictor of malignancy.

# %%
# Boxplot of Feature vs Target
plt.figure(figsize=(8,4))
sns.boxplot(x="diagnosis", y="radius_mean", data=df)
plt.xticks([0,1], ['Benign', 'Malignant'])
plt.title("Radius Mean vs Diagnosis")
plt.show()

# %% [markdown]
# ### findings
# Boxplot comparing radius_mean values for benign and malignant tumors.
#
#  Malignant tumors have higher radius_mean values on average and show more variability.
#
#  Clear separation suggests radius_mean is useful for classification.

# %%
plt.figure(figsize=(12,10))
corr = df.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### Findings
# Heatmap showing correlations between all numerical features and the diagnosis.
#
# Observation:
#
#      Strong positive correlation between radius_mean and perimeter_mean (~0.99).
#
#      radius_mean, perimeter_mean, and area_mean have strong correlation with diagnosis.
#
# These features could be highly predictive for detecting malignancy.

# %%
sns.pairplot(df[['radius_mean','texture_mean','smoothness_mean','diagnosis']], hue='diagnosis', palette='Set1')
plt.show()

# %% [markdown]
# #### Findings
#  Pairplot comparing several key features, colored by diagnosis.
#
# Malignant and benign tumors are separable in some feature combinations (e.g., radius_mean vs texture_mean).
#
# Helps identify feature pairs that can visually separate the classes.
